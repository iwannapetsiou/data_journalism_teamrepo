# %% [markdown]
# ### METHODOLODY

# %% [markdown]
# Στα πλαίσια του Εργαστηριακού Μαθήματος <i> Όψεις του Διαδικτύου - Κριτικές Προσεγγίσεις </i> με καθηγητή τον Παντελή Βατικιώτη και συνεργάτες τους Κέλλυ Κική, Θανάση Τρομπούκη και Χρυσούλα Μαρίνου, μελετήσαμε την αύξηση της μέσης μεταβολής της επιφάνειας της γης και την αύξηση των ακραίων φαινομένων σε Ελλάδα, Ιταλία, Πορτογαλία, και Ισπανία για το διάστημα 1972-2022.

# %% [markdown]
# #### Στάδιο Πρώτο: Συλλογή δεδομένων

# %% [markdown]
# Τα δεδομένα για τις θερμοκρασίες συλλέχθηκαν από [climatedata.imf.org](https://climatedata.imf.org/datasets/4063314923d74187be9596f10d034914/explore), το οποίο περιλαμβάνει στοιχεία της ετήσιας εκτίμησης της μέσης μεταβολής της θερμοκρασίας της επιφάνειας που μετρήθηκαν σε σύγκριση με τον μέσο όρο της χρονικής βάσης 1951-1980. Οι χώρες που μελετώνται είναι η Ελλάδα, η Ισπανία, η Ιταλία και η Πορτογαλία, καθώς είναι μεσογειακές χώρες οπότε θεωρούνται συγκρίσιμες, στο σύνολο του διαστήματος 1972-2022.Το διάστημα χωρίζεται είτε σε δύο περιόδους 1972-1996 & 1992-2022, είτε σε δεκαετίες, για να μπορεί να γίνει σύγκριση. (Annual_Surface_Temperature_Change)
#
# Τα δεδομένα για τα ακραία φαινόμενα πάρθηκαν από τη βάση δεδομένων της [Emdat](https://public.emdat.be/), η οποία παρέχει πρόσβαση στη βάση δεδομένων έκτακτων συμβάντων, μια ολοκληρωμένη πηγή δεδομένων για περισσότερες από 26.000 παγκόσμιες καταστροφές από το 1900 έως σήμερα. Οι καταστροφές που επιλέχθηκαν να μελετηθούν είναι οι φωτιές, πλημμύρες, ακραίες θερμοκρασίες και καταιγίδες. (akraiafainomena_data)
#
# Αν και η βάση δεδομένων της [Emdat](https://public.emdat.be/) αποτελεί έγκυρη πηγή, η περιπλοκότητα των ακραίων φαινομένων και της καταγραφής τους Αν και η βάση δεδομένων της [Emdat](https://public.emdat.be/) αποτελεί έγκυρη πηγή, η περιπλοκότητα των ακραίων φαινομένων και της καταγραφής τους αποτελεί δύσκολη υπόθεση. Σε ορισμένες περιπτώσεις, ο κύριος τύπος της καταστροφής μπορεί να είναι διαφορετικός απ'ότι σε άλλες βάσεις δεδομένων, ή μπορεί ακόμα κάποιο ακραίο φαινόμενο που έχει συμβεί σε μία συγκεκριμένη χώρα να έχει συνέπειες και σε κάποια γειτονική χώρα, και άρα, το φαινόμενο να καταχωρηθεί και στις 2 χώρες. Επίσης, όταν η βάση δεδομένων αναφέρει πως ενδεχομένως να λείπουν στοιχεία αναφέρεται κυρίως στα άλλα στοιχεία που περιλαμβάνει το dataset, τα οποία δεν χρησιμοποιήθηκαν στο συγκεκριμένο πρότζεκτ, όπως αριθμός τραυματιών, αριθμός θυμάτων. Τέλος, προβλήματα με την καταγραφή περιστατικών φαίνεται να υπάρχουν στις υπο-Σαχάριες χώρες λόγω απουσίας συστημάτων αναφοράς. Ξανά, το συγκεκριμένο πρότζεκτ δεν επηρεάζεται.
# Καταληκτικά, τα δεδομένα της βάσης είναι έγκυρα και δεν διαστρεβλώνουν τα αποτελέσματα της συγκεκριμένης έρευνας.

# %% [markdown]
# #### Στάδιο Δεύτερο: Καθαρισμός δεδομένων

# %% [markdown]
# Οι επεξεργασίες των δεδομένων έγιναν με γλώσσα προγραμματισμού python, συγκεκριμένα την βιβλιοθήκη pandas σε jupyter notebook.
#
# Από το πρώτο dataset για τις θερμοκρασίες κρατήθηκαν μόνο οι σειρές που αφορούν τις χώρες που μελετώνται, και οι στήλες για τις χρονολογίες από το 1972 έως το 2022.
#
# Από το δεύτερο dataset για τα φαινόμενα κρατήθηκαν μόνο οι σειρές που αφορούν τις χώρες και τα φαινόμενα που μελετώνται, καθώς και οι χρονολογίες 1972-2022.

# %% [markdown]
# Τα τελικά datasets που δημιουργήθηκαν και χρησιμοποιήθηκαν είναι:
#
# - merged_df : πρόκειται για ένα dataset που αποτελεί σύνδεση των δύο προηγούμενων, καθώς περιέχει τις χρονολογίες, τις χώρες, τις τιμές της μέσης μεταβολής της θερμοκρασίας και τα περιστατικά ακραίων φαινομένων.
# - merged2 : παρόμοιο με το προηγούμενο, ωστόσο περιλαμβάνει ξεχωριστή στήλη για τον κάθε τύπο ακραίου φαινομένου.
# - df5 : περιλαμβάνει μόνο τις τιμές για την μέση μεταβολή της θερμοκρασίας. Η κάθε χώρα έχει τη δική της ξεχωριστή στήλη.
# - akraiafain: περιλαμβάνει μία στήλη για την χρονολογία, μία για τις χώρες, μία με τον τύπο φαινομένων και μία με τον υπότυπο. Ο υπότυπος δεν χρησιμοποιήθηκε μιας και δεν έδινε διαφορετικές πληροφορίες απ'ότι ο τύπος.
# - disasters : δημιουργήθηκε από το προηγούμενο dataset. Για την κάθε χώρα έχει βρεθεί το σύνολο των περιστατικών για τις δύο περιόδους 1972-1996 και 1997-2022. Επίσης έχει βρεθεί και το σύνολο των περιστατικών για την κάθε χώρα για όλο το διάστημα, δηλαδή από το 1972 έως το 2022.
# - disasters_by_type : παρόμοιο με το προηγούμενο dataset, ωστόσο σε αυτό γίνεται διαχωρισμός του τύπου ακραίων φαινομένων. Ισχύει ξανά ο διαχωρισμός σε δύο περιόδους, καθώς και το σύνολο των περιστατικών ανά χώρα και τύπο για ολόκληρο το διάστημα 1972-2022.

# %% [markdown]
# Για τα dataset που περιλαμβάνουν τα περιστατικά ακραίων φαινομένων <i> merged_df, merged2 </i>:
# Στην βάση δεδομένων της [Emdat](https://public.emdat.be/) περιλαμβάνονται μόνο οι χρονολογίες που έχουν καταγραφεί περιστατικά ακραίων φαινομένων. Η κάθε σειρά αντιστοιχεί σε ένα περιστατικό. Για παράδειγμα, αν το 1972 στην Ισπανία δεν είχε γίνει κάποια πλημμύρα, δεν θα γράφει Ισπανία: Πλημμύρα:0, αλλά θα λείπει εντελώς η σειρά. Επίσης, αν το 1972 δεν είχε γίνει κανένα περιστατικό στην Ισπανία, δεν θα περιλαμβάνεται καθόλου η χρονολογία, αλλά θα προχωράει κατευθείαν στην επόμενη χρονιά που υπάρχουν περιστατικά. Η απουσία δεδομένων για μια χρονολογία στο dataset των περιστατικών δηλώνει ότι δεν υπήρξαν περιστατικά για τη συγκεκριμένη χρονολογία.
#
# Όταν έγινε συγχώνευση των δύο dataset, για τις θερμοκρασίες και τα φαινόμενα, συμπεριλήφθηκαν όλες οι ημερομηνίες, από το 1972 έως το 2022, καθώς προϋπήρχαν στο dataset με τις θερμοκρασίες. Ο κώδικας ως default έβαλε κενές τιμές στις στήλες με τα περιστατικά για τις χρονολογίες που δεν προϋπήρχαν. Ωστόσο, αυτό θα ήταν λάθος, καθώς οι χρονολογίες αυτές δεν έχουν πράγματι κενές τιμές, αλλά δεν περιλαμβάνονται εξαρχής στο dataset επειδή δεν έχουν <b> καμία </b> τιμή, δηλαδή τα περιστατικά τους είναι μηδέν. Για αυτό, οι κενές τιμές αντικαταστάθηκαν με 0 και οδηγούν σε εγκυρότερη ανάλυση.
# Το ίδιο ισχύει και για τις στήλες με τον κάθε τύπο καταστροφής ξεχωριστά. Οι κενές τιμές αντικαταστάθηκαν από το 0, καθώς δεν έχουν καταγραφεί περιστατικά.
#
# Παραδειγματικά λειτούργησε η έρευνα των Mandyam, Sukeerthi & Priya, Shanmuga & Suresh, Shalini & Srinivasan, Kavitha. (2022). A Correlation Analysis and Visualization of Climate Change using Post-Disaster Heterogeneous Datasets. 10.48550/arXiv.2205.12474. που μελετά την συσχέτιση της ανόδου της θερμοκρασίας με τα ακραία φαινόμενα.

# %% [markdown]
# #### Στάδιο Τρίτο: Ανάλυση δεδομένων

# %% [markdown]
# - Από το dataset <b> merged_df </b> , δημιουργήσαμε άλλα μικρότερα dataset για την κάθε χώρα. Καθώς θέλαμε να βρούμε τον ρυθμό μεταβολής της μέσης μεταβολής της θερμοκρασίας, χρησιμοποιήσαμε τον τύπο (μεταβολή πρόσφατης χρονιάς-μεταβολή προηγούμενης χρονιάς)/αριθμό ετών που συγκρίνεις. Αυτό το κάναμε για όλες τις χρονιές. Βρήκαμε τον μέσο όρο και βγήκε έναν αριθμό, ο οποίος δείχνει τον ρυθμό της αλλαγής με την πάροδο του χρόνου. Στη συνέχεια βρήκαμε και την διάμεσο, αλλά και χωρίσαμε το διάστημα σε δεκαετίες και ακολουθήσαμε την ίδια διαδικασία. Συγκρίναμε την διάμεσο και τον μέσο όρο που βγάλαμε για την κάθε δεκαετία για να βρούμε την περίοδο που όλες οι χώρες είχαν θερμαντικές τάσεις (2010-2022: η πιο θερμή περίοδος), αλλά και για να βρούμε πότε υπάρχει μεγάλη διαφορά στην διάμεσο και στον μέσο όρο του κάθε διαστήματος, φανερώνοντας τα διαστήματα που έχουν ακραίες τιμές.
# - Από το dataset <b> akraiafain </b>, δημιουργήθηκαν τα άλλα δύο με τίτλο <b> disasters, disasters_by_type </b>. Στο πρώτο, αποτυπώνεται η αύξηση του συνόλου των ακραίων φαινομένων από το διάστημα 1972-1996 στο 1997-2022 ανά χώρα. Στο δεύτερο, αποτυπώνεται η αύξηση του κάθε τύπου ακραίων φαινομένων από το διάστημα 1972-1996 στο 1997-2022. Για να γίνει αυτό, προστέθηκαν τα φαινόμενα που αντιστοιχούν στο κάθε διάστημα, και στην συνέχεια έγινε αφαίρεση των φαινομένων του ενός διαστήματός (1972-1996) από το άλλο (1997-2022) για να φανεί η αύξηση.
# - Για την <b> συσχέτιση </b> της θερμοκρασίας με τα ακραία φαινόμενα χρησιμοποιήθηκαν διάφορες πρακτικές. Αρχικά, το dataset με τίτλο <b> merged2 </b> δημιουργήθηκε για τον υπολογισμό της συσχέτισης του κάθε τύπου ακραιών φαινομένων με τη μέση μεταβολή της θερμοκρασίας. Ωστόσο, δεν υπήρχε κάποιο αποτέλεσμα. Τελικώς, ύστερα από συνομιλίες μας και φοιτητές στατιστικής του Πανεπιστημίου Πειραιά και του Οικονομικού Πανεπιστημίου Αθηνών, η συσχέτιση βρέθηκε για το σύνολο των χωρών χρησιμοποιώντας την διάμεσο της μέσης μεταβολής της θερμοκρασίας και την διάμεσο των περιστατικών ακραίων φαινομένων από το dataset <b> merged_df </b>. Για το σύνολο του διαστήματος 1972-2022, η συσχέτιση των δύο μεταβλητών βρίσκεται στο 0.7. Πριν το 2010 βρίσκεται στο 0.5, ενώ μετά το 2010 φτάνει στην απόλυτη συσχέτιση, δηλαδή στο 0.98.

# %% [markdown]
# #### Στάδιο Τέταρτο: Οπτικοποίηση δεδομένων

# %% [markdown]
# Όλα τα γραφήματα έγιναν μέσω [Flourish](https://app.flourish.studio/) λόγω ευχρηστίας και δυνατότητας επεξεργασίας δεδομένων εντός της εφαρμογής.
# Δοκιμάσαμε να κάνουμε και με κώδικα (matplotlib) αλλά δεν μας άρεσε εμφανισιακά.
#
# Για το πρώτο γράφημα της θερμικής απεικόνισης χρησιμοποιήθηκε το dataset <b> merged2 </b>, συγκεκριμένα οι στήλες για την χρονολογία, την χώρα και την αλλαγή της θερμοκρασίας.
#
# Ξεκινώντας από τους -1° C, το μπλε χαρακτηρίζει τη μείωση της μέσης μεταβολής θερμοκρασίας για την εκάστοτε χρονιά σε σύγκριση με την βάση 1951-1980, ενώ το κόκκινο χρώμα αντιπροσωπεύει την αύξηση της μέσης μεταβολής θερμοκρασίας που φτάνει έως και 2.5° C παραπάνω.
#
# Από την παρακάτω θερμική απεικόνιση είναι εμφανές πως υπάρχει μετάβαση από μπλε σε κόκκινα τετράγωνα καθώς προχωράμε από αριστερά (1972) προς τα δεξιά (2022), δηλαδή με το πέρασμα του χρόνου. Αυτό υποδηλώνει μια συνολική τάση προς την αύξηση της θερμοκρασίας σε αυτές τις χώρες στο διάστημα των 50 ετών που καλύπτει η μελέτη.

# %%
#import module
from IPython.display import Image
Image(filename = r'C:\Users\user\Documents\GitHub\data_journalism_teamrepo\Team_project_final\heatmap02.png')

# %% [markdown]
# Για το δεύτερο γράφημα της ανόδου της μέσης μεταβολής της θερμοκρασίας χρησιμοποιήθηκε το dataset <b> df5 </b>, καθώς η κάθε χώρα έχει τη δική της στήλη για τη μέση μεταβολή της θερμοκρασίας. Το γράφημα αναδεικνύει τις ετήσιες εκτιμήσεις της μέσης μεταβολής της θερμοκρασίας σε σχέση με μία βασική κλιματολογική περίοδο, η οποία αναφέρεται ως το διάστημα 1951-1980. Οι καμπύλες δείχνουν σημαντικές διακυμάνσεις. Ωστόσο, είναι εμφανές πως για όλες τις χώρες μπορούμε να μιλήσουμε για αύξηση της μέσης μεταβολής της θερμοκρασίας. Επίσης, αυξητική τάση της μέσης μεταβολής της θερμοκρασίας της κάθε χώρας παρατηρείται κατά τον χωρισμό του διαστήματος 1972-2022 σε δεκαετίες.

# %%
#import module
from IPython.display import Image
Image(filename = r'C:\Users\user\Documents\GitHub\data_journalism_teamrepo\Team_project_final\Surface Temperature Change02.png')

# %% [markdown]
# Για το τρίτο γράφημα για την συνολική αύξηση αύξηση των περιστατικών ακραίων φαινομένων ανά χώρα και διάστημα, χρησιμοποιήθηκε το dataset <b> disasters </b>. Προκύπτει πως τα ακραία φαινόμενα αυξάνονται την περίοδο 1997-2022 από την περίοδο 1972-1996. Ο χωρισμός της περιόδου 1972-2022 σε δύο μικρότερες περιόδους γίνεται ύστερα από την επιβεβαίωση του ειδικού Κώστα Καρτάλη, Καθηγητή Φυσικής Περιβάλλοντος και Κλίματος στο Εθνικό και Καποδιστριακό Πανεπιστήμιο Αθηνών και μέλος της Επιστημονικής Επιτροπής της Ευρωπαϊκής Ενωσης για την Κλιματική Αλλαγή, για να φανεί η αύξηση των φαινομένων.
#
# Στην Ελλάδα, τα περιστατικά στο σύνολό τους αυξήθηκαν κατά 30, στην Ιταλία κατά 46, στην Πορτογαλία κατά 21 και στην Ισπανία κατά 30.

# %%
#import module
from IPython.display import Image
Image(filename = r'C:\Users\user\Documents\GitHub\data_journalism_teamrepo\Team_project_final\Disasters02.png')

# %% [markdown]
# Για την καλύτερη κατανόηση και επεξήγηση της αύξησης των ακραίων φαινομένων, στο γράφημα 4 γίνεται διαχωρισμός των τύπων ακραίων φαινομένων ανά χώρα. Χρησιμοποιείται το dataset <b> disasters_by_type </b>. H μεγαλύτερη αύξηση να συναντάται στις πλημμύρες, ιδίως στην Ελλάδα και Ιταλία, που οι πλυμμήρες αυξήθηκαν κατά 22 και 26 αντίστοιχα. Στην Ισπανία οι πλυμμήρες αυξήθηκαν κατά 11, ενώ στην Πορτογαλία υπήρξε μόλις μία πλημμύρα παραπάνω. Ακολούθουν οι ακραίες θερμοκρασίες, οι οποίες στην Ιταλία αυξήθηκαν κατά 12, στην Πορτογαλία κατά 7, στην Ισπανία κατά 4 και στην Ελλάδα κατά 1. Οι καταιγίδες αυξήθηκαν κατά 8 στην Ισπανία και Ιταλία, κατά 7 στην Πορτογαλία και κατά 3 στην Ελλάδα. Τέλος, οι φωτιές δεν αυξήθηκαν στην Ιταλία, στην Ελλάδα αυξήθηκαν κατά 4 και στην Πορτογαλία και Ισπανία κατά 6.

# %%
#import module
from IPython.display import Image
Image(filename = r'C:\Users\user\Documents\GitHub\data_journalism_teamrepo\Team_project_final\extreme_events_by_country02.png')

# %% [markdown]
# #### Πηγές - αυθεντίες

# %% [markdown]
# Συνομιλήσαμε με:
# - Τον Πρόδρομο Ζάνη, Καθηγητής Μετεωρολογίας και Κλιματολογίας στο Τμήμα Γεωλογίας του Αριστοτελείου Πανεπιστημίου Θεσσαλονίκης (ΑΠΘ)
# - Τον Κώστα Καρτάλη, Καθηγητή Φυσικής Περιβάλλοντος και Κλίματος στο Εθνικό και Καποδιστριακό Πανεπιστήμιο Αθηνών και μέλος της Επιστημονικής Επιτροπής της Ευρωπαϊκής Ενωσης για την Κλιματική Αλλαγή
# - Τον μετερεωλόγο και Διευθυντή Προβλέψεων Καιρού & Διεθνών Επιχειρήσεων James Purpura,
# - Τον ατμοσφαιρικό επιστήμονα Frank Brody.

# %% [markdown]
# Πληροφορίες για τα δεδομένα μας πήραμε από:
#
# - [Euronews](https://www.euronews.com/green/2023/07/06/spain-is-getting-hotter-drier-and-more-flammable-due-to-climate-change-greenpeace-warns)
# - [Weatheronline.co.uk](https://www.weatheronline.co.uk/reports/climate/Spain.htm?fbclid=IwAR0ACJhL2qo03n52W4Mwbup2EkTCXfqGHyM6qsngI0bG4fNOVN6jD6FHRbw#google_vignette)
# - [Climeworks.com](https://climeworks.com/blog/extreme-weather-events-in-europe)
# - [Ευρωπαϊκή Επιτροπή](https://climate.ec.europa.eu/climate-change/causes-climate-change_el)
# - [United Nations Climate Action](https://www.un.org/en/climatechange/what-is-climate-change)
# - [NRDC](https://www.nrdc.org/stories/what-are-causes-climate-change)
# - [CNN](https://edition.cnn.com/2023/12/05/climate/past-decade-warmest-record-wmo-emissions/index.html)
# - [NRDC](https://www.nrdc.org/stories/what-are-causes-climate-change)
# - [La Moncloa](https://www.lamoncloa.gob.es/lang/en/espana/historyandculture/geography/Paginas/index.aspx)
# - [Dianeosis](https://www.dianeosis.org/2021/10/oi-synepeies-tis-klimatikis-allagis-stin-ellada/)
# - [Ευρωπαϊκό Κοινοβούλιο](https://www.europarl.europa.eu/news/el/headlines/society/20180703STO07123/klimatiki-allagi-stin-europi-stoicheia-kai-arithmoi)
# - [Real Instituto Elcano](https://www.realinstitutoelcano.org/en/work-document/climate-change-in-spain-friend-and-foe-causes-consequences-and-response-wp/)
# - [C2ES](https://www.c2es.org/content/changes-in-climate/?fbclid=IwAR0ZuPrxLupzA8DMYyBcVwnx_rZiTvpQwqYYcc0dKFzHwI_mvTGSQhEPVn0)
# - [Undestanding Global Change](https://ugc.berkeley.edu/background-content/temperature/?fbclid=IwAR13UNTqIw3gspQYTJAvEb3uvlvrcXpQVBVlf7z--bSX2B6w-i9nAOXGVJM)
# - [Odyssee-Mure](https://www.odyssee-mure.eu/publications/efficiency-by-sector/transport/distance-travelled-by-car.html)
# - Πανεπιστήμιο Πατρών
