# %% [markdown]
# # Data Project Pitch - ΟΜΑΔΑ Α

# %% [markdown]
# ### Σύνοψη

# %% [markdown]
# <i> Kλιματική αλλαγή: άνοδος της θερμοκρασίας και συσχέτιση με τα ακραία καιρικά φαινόμενα.
#
# Θα κάνουμε μία εργασία για την κλιματική αλλαγή και τη συσχέτισή της με ακραία καιρικά φαινόμενα. Η εργασία θα αφορά το διάστημα 2000 με 2022. Κύρια χώρα θα είναι η Ελλάδα. Κατά τη σύγκριση της Ελλάδας με άλλες χώρες όσον αφορά τις φυσικές καταστροφές, επιλέξαμε  χώρες που έχουν παρόμοια γεωγραφικά, κλιματικά και γεωλογικά χαρακτηριστικά. Αυτό θα βοηθήσει στην πιο δίκαιη και αποτελεσματική σύγκριση. Αυτές οι χώρες είναι:
#
# -Ιταλία: Η Ιταλία βρίσκεται στην ίδια γεωγραφική περιοχή με την Ελλάδα και αντιμετωπίζει παρόμοιους κινδύνους, όπως σεισμούς και πλημμύρεους.
#
# -Ισπανία: Ανάλογα με την περιοχή, η Ισπανία μπορεί να αντιμετωπίζει προβλήματα όπως πυρκαγιές και πλημμύρες.
#
# -Πορτογαλία: Η Πορτογαλία μπορεί να είναι ενδιαφέρουσα για σύγκριση, ειδικά όσον αφορά τις πυρκαγιές και τις κλιματικές αλλαγές.
#
# -Κροατία: Καθώς βρίσκεται κοντά στην Ελλάδα και έχει παρόμοια γεωγραφικά χαρακτηριστικά, η Κροατία μπορεί να αντιμετωπίζει παρόμοιους κινδύνους.
#
# Ο λόγος που κάνουμε την σύγκριση είναι για να δούμε αν χώρες με παρόμοια γεωγραφικά χαρακτηριστικά αντιμετωπίζουν τα ίδια προβλήματα από την κλιματική αλλαγή.
# </i>

# %% [markdown]
# ### Έμπνευση

# %% [markdown]
#  <i> Αντλήσαμε έμπνευση από </i> https://ourworldindata.org/natural-disasters#natural-disasters-data-explorer
#  Είναι γνωστό πως πλέον το πρόβλημα της κλιματικής αλλαγής μας αφορά όλους. Παράλληλα, η αύξηση των ακραίων καιρικών φαινομένων στην χώρα μας δεν φαίνεται να είναι άσχετη από την κλιματική αλλαγή. Επιδιώκουμε να δούμε εάν όντως, η άνοδος των θερμοκρασιών αυξάνει και τα ακραία καιρικά φαινόμενα.

# %% [markdown]
# ### Περαιτέρω πληροφορίες για το θέμα σας

# %% [markdown]
# - <b>Τίτλος εργασίας</b>: <i> Η υπερθέρμανση του πλανήτη και τα ακραία καιρικά φαινόμενα</i>
# <br><br>
# - <b>Δεδομένα</b>:
# <i> Αυτό το λινκ <i> https://climatedata.imf.org/datasets/4063314923d74187be9596f10d034914/explore περιλαμβάνει μία βάση δεδομένων για τις ετήσιες εκτιμήσεις της μέσης μεταβολής της θερμοκρασίας της επιφάνειας που μετρήθηκαν σε σχέση με μια βασική κλιματολογία, που αντιστοιχεί στην περίοδο 1951-2022. <i> Με αυτό θα βρούμε την αλλαγή της θερμοκρασίας στις χώρες που μας ενδιαφέρουν.
#
# <i>Αυτό το λινκ https://wmo.asu.edu/content/world-meteorological-organization-global-weather-climate-extremes-archive έχει διάφορα δεδομένα για ακραία καιρικά φαινόμενα </i>
#
# Καθώς θέλουμε να συσχετίσουμε την άνοδο της θερμοκρασίας με τις φυσικές καταστροφές / ακραία καιρικά φαινόμενα, χρειαζόμαστε στοιχεία που να αφορούν τις χώρες Ελλάδα, Ιταλία, Ισπανία, Πορτογαλία, Κροατία και τα ακραία καιρικά φαινόμενα σε αυτές.
# Για την Ελλάδα στην οποία και επικεντρωνόμαστε,  η ιστοσελίδα της ΕΜΥ http://www.emy.gr/emy/el/climatology/climatology_extreme προσφέρει σε pdf τα ακραία καιρικά φαινόμενα ανά έτος από το 2014 έως το 2022.
#
# Σε αυτό το λινκ https://ourworldindata.org/natural-disasters?fbclid=IwAR21WXxVrKqlcdtxe4iuD2KUu7oKzprhef46aUuhKr-OAl7tosEuaSpy5X8#annual-deaths-from-natural-disasters υπάρχουν στοιχεία για τους θανάτους που οφείλονται σε φυσικές καταστροφές όπως :σεισμοί, πλημμύρες, ηφαίστεια, κυκλώνες, πυρκαγιές, αστραπές, καύσωνες κτλ. Εμείς ίσως επικεντρωθούμε σε μερικά από αυτά.
#
# Σε αυτό το λινκ υπάρχουν δεδομένα για φυσικές καταστροφές από το 2000 https://public.emdat.be/data.be/data, τα οποία κατηγοριοποιούνται ανά είδος, χώρα. Αναφέρει και τα προβλήματα που δημιουργήθηκαν από το εκάστοτε πρόβλημα.

# %% [markdown]
# <b> Πιθανά προβλήματα/ανασφάλειες/απορίες</b>:
#
# - <i> Αρκούν τα δεδομένα; </i>
# - <i> έχει νόημα αυτή η ανάλυση, ή μοιάζει περισσότερο με μία βεβιασμένη συσχέτιση; </i>
# - <i>δεν αντιστοιχούν όλα τα dataset στο διάστημα που θέλουμε </i>
# - <i>Να κλείσουμε την έρευνα με τις πολιτικές που έχει υιοθετήσει η κάθε χώρα για την κλιματική αλλαγή; </i>
# - <i>τι να αλλάξουμε / αφαιρέσουμε / προσθέσουμε; </i>

# %% [markdown]
# ### Ερευνητικά ερωτήματα

# %% [markdown]
# <b> Υπάρχει συσχέτιση της υπερθέρμανσης του πλανήτη και της αύξησης των ακραίων καιρικών φαινομένων; έχουν αυξηθεί όντως τα ακραία καιρικά φαινόμενα; </b>
#
# <i> Yποερωτήματα (όχι όλα αν δεν χρειάζονται) </i>
# -  Πόσο έχει μεταβληθεί η θερμοκρασία στην Ελλάδα από το 2000 και μετά;
# -  Ποιο είναι το ποσοστό των ακραίων καιρικών φαινομένων στην Ελλάδα;
# -  Αντίστοιχα, πόσο έχει μεταβληθεί η θερμοκρασία σε Ιταλία, Ισπανία, Πορτογαλία, Κροατία;
# -  Ποιο είναι το ποσοστό των ακραίων καιρικών φαινομένων σε αυτές τις χώρες;
# -  Ποιο ποσοστό των θανάτων των χωρών αυτών οφείλεται σε ακραία καιρικά φαινόμενα;

# %% [markdown]
# ### Προέρευνα/δουλειά που έχετε ήδη κάνει στο πλαίσιο του σχεδιασμού του πρότζεκτ

# %% [markdown]
# - <i>Έχουμε βρει μερικές βάσεις δεδομένων, δεν τις έχουμε καθαρίσει, απλώς τις έχουμε κοιτάξει. Σίγουρα χρειαζόμαστε και άλλες </i>

# %% [markdown]
# ## Απαντήστε "YES" ή "NO" στα παρακάτω ερωτήματα
# <i>(Στο στάδιο της πρότασης θέματος που βρίσκεστε, το αναμενόμενο είναι YES. Όσα περισσότερα NO, τόσο λιγότερο έχετε προετοιμαστεί και, άρα, χρειάζεται να σχεδιάσετε καλύτερα το πρότζεκτ σας.)</i>

# %%
input("Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
# Out:
# Έχετε ψάξει για πηγές δεδομένων για το θέμα που θέλετε να κάνετε; YES
# 'YES'

# %%
input("Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε;")
# Out:
# Έχετε βρει δεδομένα/πηγές δεδομένων για το θέμα που θέλετε να κάνετε; YES
# 'YES'

# %%
input("Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει;")
# Out:
# Έχετε περάσει χρόνο εξερευνώντας τα δεδομένα σας; Έχετε καταλάβει τι έχετε, σε ποια μορφή είναι και ενδεχομένως τι σας λείπει; YES
# 'YES'

# %%
input("Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας;")
# Out:
# Έχετε διατυπώσει τα ερευνητικά ερωτήματά σας; YES
# 'YES'

# %%
input("Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας;")
# Out:
# Έχετε σκεφτεί πώς θα αναλύσετε τα δεδομένα σας, για να απαντήσετε τα ερευνητικά ερωτήματά σας; YES
# 'YES'

# %%
input("Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story;")
# Out:
# Έχετε αρχίσει να σκέφτεστε πώς θα μπορούσατε να οπτικοποιήσετε τις αναλύσεις σας για το τελικό σας story; NO
# 'NO'

# %%
input("Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2;")
# Out:
# Έχετε καταθέσει το pitch σας (το προτεινόμενο θέμα σας) σε ένα notebook με filename PITCH_ΟΝΟΜΑΤΕΠΩΝΥΜΟ1_ΟΝΟΜΑΤΕΠΩΝΥΜΟ2; YES
# 'YES'
